# %% [markdown]
# https://towardsdatascience.com/apply-rfm-principles-to-cluster-customers-with-k-means-fef9bcc9ab16

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import random
import seaborn as sns
import pandas as pd
import collections
pd.set_option('display.max_columns', 50)
from googletrans import Translator
from tqdm import tqdm

# %%
orders = pd.read_csv('../Data/Processed/orders.csv', encoding='utf-8')

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# ## Translation

# %%
comments = ""
for s in tqdm(orders.review_comment_title) :
    comments += str(s)
    comments += '\n '
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████| 95980/95980 [00:08<00:00, 11034.75it/s]

# %%
translator = Translator()
size = len(comments)
english_comments = translator.translate(comments[:int(size/100)], src='Pt', dest='en')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-35-b8c274ad164f> in <module>()
#       1 translator = Translator()
#       2 size = len(comments)
# ----> 3 english_comments = translator.translate(comments[:int(size/100)], src='Pt', dest='en')
#
# C:\Anaconda\envs\ada\lib\site-packages\googletrans\client.py in translate(self, text, dest, src)
#     170
#     171         origin = text
# --> 172         data = self._translate(text, dest, src)
#     173
#     174         # this code will be updated when the format is changed.
#
# C:\Anaconda\envs\ada\lib\site-packages\googletrans\client.py in _translate(self, text, dest, src)
#      79         r = self.session.get(url, params=params)
#      80
# ---> 81         data = utils.format_json(r.text)
#      82         return data
#      83
#
# ...

# %%
orders.dropna(inplace=True)

# %%
def translate_text(t) :
    translator = Translator()
    return translator.translate(t, src='Pt', dest='en')

# %%
#Run it in the night
translated = []
for s in tqdm(orders.review_comment_title) :
    translated.append(translate_text(s))
# Out:
#   0%|                                                                                        | 0/94623 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-17-09a90e4aeb93> in <module>()
#       2 translated = []
#       3 for s in tqdm(orders.review_comment_title) :
# ----> 4     translated.append(translate_text(s))
#
# <ipython-input-14-65db0b51b5a8> in translate_text(t)
#       1 def translate_text(t) :
#       2     translator = Translator()
# ----> 3     return translator.translate(t, src='Pt', dest='en')
#
# C:\Anaconda\envs\ada\lib\site-packages\googletrans\client.py in translate(self, text, dest, src)
#     170
#     171         origin = text
# --> 172         data = self._translate(text, dest, src)
#     173
#     174         # this code will be updated when the format is changed.
#
# ...

# %%
#translated[72].text

# %%
#orders.review_comment_title = orders.review_comment_title.apply(lambda s : translate_text(s))

# %%
#orders.review_comment_message = orders.review_comment_message.apply(lambda s : translate_text(s))

# %%
orders = orders.reindex(sorted(orders.columns), axis=1)

# %%
orders.head()
# Out:
#              customer_city                       customer_id customer_state  \
# 0                sao paulo  9ef432eb6251297304e76186b10a928d             SP
# 1                barreiras  b0830fb4747a6c6d20dea0b8c802d7ef             BA
# 2               vianopolis  41ce2a54c0b03bf3443c3d931a367089             GO
# 3  sao goncalo do amarante  f88197465ea7920adcdbec7375364d82             RN
# 4              santo andre  8ab97904e6daea8866dbdbc4fb7aad2c             SP
#
#                  customer_unique_id  customer_zip_code_prefix  freight_value  \
# 0  7c396fd4830fd04220f754e42b4e5bff                    3149.0           8.72
# 1  af07308b275d755c9edb36a90c618231                   47813.0          22.76
# 2  3a653a41f6f9fc3d2a113cf8398680e8                   75265.0          19.22
# 3  7c142cf63193a1473d2e66489a9ae977                   59296.0          27.20
# 4  72632f0f9dd73dfee390c9b22eb56dd6                    9195.0           8.72
#
# ...

# %%
sns.catplot(x="order_status", y="price", kind="bar", hue="review_score", data=orders)

# %%
orders.groupby('product_category_name').count().hist()

# %%
orders.review_comment_message
# Out:
# 0        Não testei o produto ainda, mas ele veio corre...
# 1                                     Muito bom o produto.
# 2                                   O cliente não comentou
# 3        O produto foi exatamente o que eu esperava e e...
# 4                                   O cliente não comentou
# 5                                   O cliente não comentou
# 6                                   O cliente não comentou
# 7                                   O cliente não comentou
# 8                                   O cliente não comentou
# 9                               Aguardando retorno da loja
# 10                                  O cliente não comentou
# 11                                  O cliente não comentou
# 12                                  O cliente não comentou
# 13                                       Gostei do produto
# 14       Obrigado pela atenção. Lojas lannister perfeit...
# 15       o produto é bom mais a lixeira me decepcionou ...
# ...
