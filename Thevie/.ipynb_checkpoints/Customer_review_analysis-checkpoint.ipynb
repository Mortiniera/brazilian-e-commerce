# %% [markdown]
# Source and inspiration
# https://www.kaggle.com/krnilo/customer-reviews-analysis-brazilian-e-commerce

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import seaborn as sns
import pandas as pd
from collections import Counter
pd.set_option('display.max_columns', 50)
from googletrans import Translator
from tqdm import tqdm

# %%
orders = pd.read_csv('../Data/Processed/orders.csv', encoding='utf-8')

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date  payment_sequential payment_type  \
# 0           2017-10-18 00:00:00                 1.0  credit_card
# 1           2018-08-13 00:00:00                 1.0       boleto
# 2           2018-09-04 00:00:00                 1.0  credit_card
# 3           2017-12-15 00:00:00                 1.0  credit_card
# 4           2018-02-26 00:00:00                 1.0  credit_card
#
#    payment_installments  payment_value                customer_unique_id  \
# 0                   1.0          18.12  7c396fd4830fd04220f754e42b4e5bff
# 1                   1.0         141.46  af07308b275d755c9edb36a90c618231
# 2                   3.0         179.12  3a653a41f6f9fc3d2a113cf8398680e8
# 3                   1.0          72.20  7c142cf63193a1473d2e66489a9ae977
# 4                   1.0          28.62  72632f0f9dd73dfee390c9b22eb56dd6
#
#    customer_zip_code_prefix            customer_city customer_state  \
# 0                    3149.0                sao paulo             SP
# 1                   47813.0                barreiras             BA
# 2                   75265.0               vianopolis             GO
# 3                   59296.0  sao goncalo do amarante             RN
# 4                    9195.0              santo andre             SP
#
#                           review_id  review_score    review_comment_title  \
# 0  a54f0611adc9ed256b57ede6b6eb5114           4.0  O cliente não comentou
# 1  8d5266042046a06655c8db133d120ba5           4.0        Muito boa a loja
# 2  e73b67b67587f7644d5bd1a52deb1b01           5.0  O cliente não comentou
# 3  359d03e676b3c069f62cadba8dd3f6e8           5.0  O cliente não comentou
# 4  e50934924e227544ba8246aeb3770dd4           5.0  O cliente não comentou
#
#                               review_comment_message review_creation_date  \
# 0  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 1                               Muito bom o produto.  2018-08-08 00:00:00
# 2                             O cliente não comentou  2018-08-18 00:00:00
# 3  O produto foi exatamente o que eu esperava e e...  2017-12-03 00:00:00
# 4                             O cliente não comentou  2018-02-17 00:00:00
#
#   review_answer_timestamp  order_item_id                         seller_id  \
# 0     2017-10-12 03:43:48            1.0  3504c0cb71d7fa48d967e0e4c94d59d9
# 1     2018-08-08 18:37:50            1.0  289cdb325fb7e7f891c38608bf9e0962
# 2     2018-08-22 19:07:58            1.0  4869f7a5dfa277a7dca6462dcf3b52b2
# 3     2017-12-05 19:21:58            1.0  66922902710d126a0e7d26b0e3805106
# 4     2018-02-18 13:02:51            1.0  2c9e548be18521d1c43cde1c582c6de8
#
#                          product_id  shipping_limit_date   price  \
# 0  87285b34884572647811a353c7ac498a  2017-10-06 11:07:15   29.99
# 1  595fac2a385ac33a80bd5114aec74eb8  2018-07-30 03:24:27  118.70
# 2  aa4383b373c6aca5d8797843e5594415  2018-08-13 08:55:23  159.90
# 3  d0b61bfb1de832b15ba9d266ca96e5b0  2017-11-23 19:45:59   45.00
# 4  65266b2da20d04dbe00c5c2d3bb7859e  2018-02-19 20:31:37   19.90
#
#    freight_value  product_category_name  product_name_lenght  \
# 0           8.72  utilidades_domesticas                 40.0
# 1          22.76             perfumaria                 29.0
# 2          19.22             automotivo                 46.0
# 3          27.20               pet_shop                 59.0
# 4           8.72              papelaria                 38.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       268.0                 4.0             500.0
# 1                       178.0                 1.0             400.0
# 2                       232.0                 1.0             420.0
# 3                       468.0                 3.0             450.0
# 4                       316.0                 4.0             250.0
#
#    product_length_cm  product_height_cm  product_width_cm
# 0               19.0                8.0              13.0
# 1               19.0               13.0              19.0
# 2               24.0               19.0              21.0
# 3               30.0               10.0              20.0
# 4               51.0               15.0              15.0

# %%
orders.order_status.unique()
# Out:
# array(['delivered', 'canceled', '2017-09-11 01:28:36',
#        '2017-09-21 12:25:26'], dtype=object)

# %% [markdown]
# # 1. Descriptive analysis

# %% [markdown]
# https://www.kaggle.com/krnilo/customer-reviews-analysis-brazilian-e-commerce

# %%
orders['comment_present'] = orders.review_comment_message != 'O cliente não comentou'

# %%
sns.catplot(x='review_score', kind='count', data=orders, hue='comment_present')\
.set(xlabel='Review Score', ylabel='Number of Reviews', title='Reviews distribution'), orders.review_score.describe()
# Out:
# (<seaborn.axisgrid.FacetGrid at 0x281eaf6e1d0>, count    95978.000000
#  mean         4.144356
#  std          1.294795
#  min          1.000000
#  25%          4.000000
#  50%          5.000000
#  75%          5.000000
#  max          5.000000
#  Name: review_score, dtype: float64)

# %% [markdown]
# Most reviews are good ones, we can see that the average review score is 4.14, with a median at 5. However, we notice that the number of reviews with a score of 1 is bigger than 2/3 score. Furthemore, almost half of the orders did not receive any customer feedback. Looking at the difference between 1 score reviews and 5 ones, we notice that customers who answered positively in the survey are less likely to leave comments while customers who gave bad feedback are more likely to do it.

# %%
orders[(orders['comment_present'] == True) & (orders['review_score'] == 1)].review_comment_message.map(lambda x : len(str(x))).hist()

# %%
orders[(orders['comment_present'] == True) & (orders['review_score'] == 5)].review_comment_message.map(lambda x : len(str(x))).hist()

# %% [markdown]
# Finally, when looking at the survey comments between negative (score = 1) and positive (score = 5) feedbacks, we notice that positive feedbacks tend to be shorter and less succint than negative ones.

# %% [markdown]
# # 2. Sentiment Analysis

# %% [markdown]
# Now, let's dive into the content of those comments and see the difference between bad an positive ones. We will try to discover if there are recurrent pattern regarding negative or positive patterns, i.e, what were the customers complaining about or what did they really like ?
#
# Hence, we will only focus on orders for which the customers did leave an answer in the survey and for which the review score is 1 or 5. For those which they did not, we we will try to discover with the other features what could have gone wrong.

# %%
orders_commented = orders[orders['comment_present'] == True]
orders_commented = orders_commented[(orders_commented['review_score'] == 1) | (orders_commented['review_score'] == 5)]

# %% [markdown]
# ## 2.1 Satisfaction answer delay

# %%
orders_commented.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27903 entries, 3 to 95977
# Data columns (total 37 columns):
# order_id                         27903 non-null object
# customer_id                      27903 non-null object
# order_status                     27903 non-null object
# order_purchase_timestamp         27903 non-null object
# order_approved_at                27903 non-null object
# order_delivered_carrier_date     27903 non-null object
# order_delivered_customer_date    27903 non-null object
# order_estimated_delivery_date    27903 non-null object
# payment_sequential               27903 non-null float64
# payment_type                     27903 non-null object
# payment_installments             27903 non-null float64
# payment_value                    27903 non-null float64
# customer_unique_id               27903 non-null object
# customer_zip_code_prefix         27903 non-null float64
# customer_city                    27903 non-null object
# customer_state                   27903 non-null object
# review_id                        27903 non-null object
# review_score                     27903 non-null float64
# review_comment_title             27903 non-null object
# review_comment_message           27903 non-null object
# review_creation_date             27901 non-null object
# review_answer_timestamp          27901 non-null object
# order_item_id                    27901 non-null float64
# seller_id                        27901 non-null object
# product_id                       27901 non-null object
# shipping_limit_date              27901 non-null object
# price                            27901 non-null float64
# freight_value                    27901 non-null float64
# product_category_name            27476 non-null object
# product_name_lenght              27476 non-null float64
# product_description_lenght       27476 non-null float64
# product_photos_qty               27476 non-null float64
# product_weight_g                 27891 non-null float64
# product_length_cm                27891 non-null float64
# product_height_cm                27891 non-null float64
# product_width_cm                 27891 non-null float64
# comment_present                  27903 non-null bool
# dtypes: bool(1), float64(15), object(21)
# memory usage: 7.9+ MB

# %%
orders_commented = orders_commented.astype({"order_status" : 'category', \
                       "order_purchase_timestamp" : 'datetime64[ns]', "order_approved_at" : 'datetime64[ns]', \
                       "order_delivered_carrier_date" : 'datetime64[ns]', "order_delivered_customer_date" : 'datetime64[ns]', \
                       "order_estimated_delivery_date" : 'datetime64[ns]', 'review_creation_date':'datetime64[ns]', \
                        "review_answer_timestamp" : 'datetime64[ns]', "shipping_limit_date" : 'datetime64[ns]', \
                        "product_category_name" : 'category', 
                       })

# %%
orders_commented['delay'] = ((orders_commented['review_answer_timestamp'] - orders_commented['review_creation_date']).dt.days)

# %%
bins = [-1, 0, 1, 2, 3, 99999]
labels = ['0', '1', '2', '3', '4+']
orders_commented['delay_group'] = pd.cut(orders_commented['delay'], bins, labels=labels)

# %%
sns.catplot(
    x='delay_group', 
    kind='count', 
    data=orders_commented,
    hue='review_score',
).set(xlabel='Time to answer to survey (days)', ylabel='Number of Reviews');

# %% [markdown]
# Looking at the plot above, we see that customers who answered negatively tends to answer earlier than customers with positive experience.

# %% [markdown]
# ## 2.2 Customer Experience

# %% [markdown]
# What customers like and dislike the most about Olist's experience ?

# %%
import nltk
from wordcloud import WordCloud
import unicodedata

# %%
def remove_accents(text):
    return unicodedata.normalize('NFKD', text).encode('ascii', errors='ignore').decode('utf-8')

STOP_WORDS = set(remove_accents(w) for w in nltk.corpus.stopwords.words('portuguese'))
STOP_WORDS.remove('nao') # This word is key to understand delivery problems later


def comments_to_words(comment):
    lowered = comment.lower()
    normalized = remove_accents(lowered)
    tokens = nltk.tokenize.word_tokenize(normalized)
    words = tuple(t for t in tokens if t not in STOP_WORDS and t.isalpha())
    return words

def words_to_ngrams(words):
    unigrams, bigrams, trigrams = [], [], []
    for comment_words in words:
        unigrams.extend(comment_words)
        bigrams.extend(' '.join(bigram) for bigram in nltk.bigrams(comment_words))
        trigrams.extend(' '.join(trigram) for trigram in nltk.trigrams(comment_words))
    
    return unigrams, bigrams, trigrams

def plot_freq(tokens, color):
    nltk.FreqDist(tokens).plot(25, cumulative=False, color=color)

# %%
orders_commented['review_comment_words'] = orders_commented['review_comment_message'].apply(comments_to_words)

positive_reviews = orders_commented[orders_commented['review_score'] == 5]
negative_reviews = orders_commented[orders_commented['review_score'] == 1]

positive_unigrams, positive_bigrams, positive_trigrams = words_to_ngrams(positive_reviews['review_comment_words'])
negative_unigrams, negative_bigrams, negative_trigrams = words_to_ngrams(negative_reviews['review_comment_words'])

# %% [markdown]
# **Are there important topics where extra caution is advised ?**

# %%
top20_positive = list(dict(Counter(positive_trigrams).most_common(20)).keys())

# %%
top20_negative = list(dict(Counter(negative_trigrams).most_common(20)).keys())

# %%
positive_comments = []
negative_comments = []

# %%
from googletrans import Translator
from tqdm import tqdm

# %%
for i in tqdm(range(len(top20_positive))) :
    translator = Translator()
    positive_comments.append(translator.translate(top20_positive[i], src='Pt', dest='en'))
    negative_comments.append(translator.translate(top20_negative[i], src='Pt', dest='en'))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:15<00:00,  1.42it/s]

# %%
positive_comments = list(map(lambda x : x.text, positive_comments))
negative_comments = list(map(lambda x : x.text, negative_comments))

# %%
comments_topics = pd.DataFrame({'positive_comments' : positive_comments, 'negative_comments' : negative_comments})

# %%
comments_topics
# Out:
#              positive_comments              negative_comments
# 0      arrived before deadline  I did not recieve the product
# 1             well before term    I have not received it yet.
# 2        delivered before term          product not delivered
# 3         delivery before term        product has not arrived
# 4       product arrived before                product not yet
# 5          arrived well before          it did not arrive yet
# 6     product delivered before   I did not receive the moment
# 7          Super fast delivery              not yet delivered
# 8        great quality product     I have not received it now
# 9            ahead of schedule               Related searches
# 10         before term product           I received a product
# 11        before expected date              I want money back
# 12      I received before term  I did not receive merchandise
# 13       before long recommend            product came defect
# 14  before stipulated deadline                I got no answer
# 15       fast delivery product         I received product yet
# 16            delivered within    I did not receive it today.
# 17        good quality product        I got the wrong product
# 18  product delivered deadline          I bought two products
# 19        product arrived well             product came wrong

# %% [markdown]
# When looking at the table :
#     - We got positive feedback from the customers mainly because the delivery service was great in terms of delivery time and because of the good product quality.
#     - Among negative sentiments however, the customers complains about the  delivery service : they either received the wrong product or they had to answer the survey before even getting the product. Furthermore, they also complained a lot about the bad quality of the product and want a refund.

# %%
np.save('comments_topics.npy', comments_topics)

# %% [markdown]
# **Hence, during our Customer sentiment analysis, we noticed some directions where Olist can elaborate strategies for customer retentions. Although most customers seem happy, since the average score is 4.1, some of them are still not satisfied enough. Since we know that customer acquisition may be sometimes harder than customer retention, we advise Olist to pay attention to the sectors where customers are mainly satisfied (product quality and delivery service quality) and to be even more careful why in the same areas some customers are not satisfied enough. We may want to further this analysis, taking into account that there are lot of sellers in Olist platform, and it might be a good idea to spot which sellers do provide a lower quality product and delivery service to present to the stakeholders which will be in charge of taking actual decisions.**

# %% [markdown]
# # 3 Silent customers

# %% [markdown]
# Some customers didn't write a review. But why are they happy or mad?

# %%
silent_orders = orders[orders['comment_present'] == False]
silent_orders = silent_orders[(silent_orders['review_score'] == 1) | (silent_orders['review_score'] == 5)]

# %%
silent_orders = silent_orders.astype({"order_status" : 'category', \
                       "order_purchase_timestamp" : 'datetime64[ns]', "order_approved_at" : 'datetime64[ns]', \
                       "order_delivered_carrier_date" : 'datetime64[ns]', "order_delivered_customer_date" : 'datetime64[ns]', \
                       "order_estimated_delivery_date" : 'datetime64[ns]', 'review_creation_date':'datetime64[ns]', \
                        "review_answer_timestamp" : 'datetime64[ns]', "shipping_limit_date" : 'datetime64[ns]', \
                        "product_category_name" : 'category', 
                       })

# %%
sns.catplot(
    x='review_score', 
    kind='count', 
    data=silent_orders)

# %%
negative_silent_orders = silent_orders[silent_orders['review_score'] == 1]

# %%
negative_silent_orders.head()
# Out:
#                              order_id                       customer_id  \
# 7    76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 71   82bce245b1c9148f8d19a55b9ff70644  388025bec8128ff20ec1a316ed4dcf02
# 93   6a0a8bfbbe700284feb0845d95e0867f  68451b39b1314302c08c65a29f1140fc
# 241  f31535f21d145b2345e2bf7f09d62322  ed532487db04478dfba09d112649fc13
# 309  16c24987724018f73b746aacfbb5f8e8  ffdc2af7160aed3bad21cbc8ec68c0c5
#
#     order_status order_purchase_timestamp   order_approved_at  \
# 7      delivered      2017-01-23 18:29:09 2017-01-25 02:50:47
# 71     delivered      2017-04-20 17:15:46 2017-04-21 05:15:56
# 93     delivered      2017-11-22 11:32:22 2017-11-22 11:46:50
# 241    delivered      2018-02-01 07:47:34 2018-02-01 08:10:31
# 309    delivered      2017-05-20 02:48:00 2017-05-23 03:50:25
#
#     order_delivered_carrier_date order_delivered_customer_date  \
# 7            2017-01-26 14:16:31           2017-02-02 14:08:10
# 71           2017-04-24 09:34:13           2017-05-10 09:17:55
# 93           2017-11-27 13:39:35           2017-12-28 19:43:00
# 241          2018-02-02 00:24:34           2018-04-23 15:49:34
# 309          2017-06-05 13:58:19           2017-06-16 16:52:02
#
#     order_estimated_delivery_date  payment_sequential payment_type  \
# 7                      2017-03-06                 1.0       boleto
# 71                     2017-05-12                 1.0       boleto
# 93                     2017-12-11                 1.0  credit_card
# 241                    2018-03-05                 2.0      voucher
# 309                    2017-06-09                 1.0       boleto
#
#      payment_installments  payment_value                customer_unique_id  \
# 7                     1.0          35.95  39382392765b6dc74812866ee5ee92a7
# 71                    1.0         267.80  f9effeed3df9ae063a58c0759b96f8b2
# 93                    5.0         101.74  781ae350edb16842380e81d7c7feb431
# 241                   1.0         100.00  51ac8560948d44d4ffa33f2680569a20
# 309                   1.0         180.45  49eb55b407f86a1e87d7898594e65c90
#
#      customer_zip_code_prefix   customer_city customer_state  \
# 7                     99655.0    faxinalzinho             RS
# 71                    85804.0        cascavel             PR
# 93                    20740.0  rio de janeiro             RJ
# 241                   24350.0         niteroi             RJ
# 309                   30130.0  belo horizonte             MG
#
#                             review_id  review_score    review_comment_title  \
# 7    fc4af8aea8ec3f1a3cd181d3d0cadbd5           1.0  O cliente não comentou
# 71   fd793fea4f4a2ddcc956561144b6c04e           1.0  O cliente não comentou
# 93   1dbe272d8884775c73d0d164bd1ff844           1.0  O cliente não comentou
# 241  64c5384f6f6ccdb5b514f1ebfbba5a03           1.0  O cliente não comentou
# 309  fb7793b81898e28816f37c40bef6c9f8           1.0  O cliente não comentou
#
#      review_comment_message review_creation_date review_answer_timestamp  \
# 7    O cliente não comentou           2017-02-03     2017-02-05 01:58:35
# 71   O cliente não comentou           2017-05-11     2017-05-12 11:25:49
# 93   O cliente não comentou           2017-12-13     2017-12-19 22:50:36
# 241  O cliente não comentou           2018-03-07     2018-03-07 12:30:01
# 309  O cliente não comentou           2017-06-14     2017-06-14 10:56:09
#
#      order_item_id                         seller_id  \
# 7              1.0  63b9ae557efed31d1f7687917d248a8d
# 71             5.0  c8417879a15366a17c30af34c798c332
# 93             1.0  4a3ca9315b744ce9f8e9374361493884
# 241            1.0  91f0eec23d4a61d7d7caeefa3f0ad1ca
# 309            1.0  973f21788dfab357250f69a8dcb7ddee
#
#                            product_id shipping_limit_date  price  \
# 7    ac1789e492dcd698c5c10b97a671243a 2017-01-27 18:29:09   19.9
# 71   a5a0e71a81ae65aa335e71c06261e260 2017-04-27 05:15:56  190.0
# 93   f8a8f05a35976a91aed5cccc3992c357 2017-11-28 11:46:50   83.9
# 241  f196248e8b5d060cca414a664ea9a76f 2018-02-08 08:10:31  199.0
# 309  f3dbf072e817667fbde052aae313cce1 2017-05-29 03:50:25  135.0
#
#      freight_value  product_category_name  product_name_lenght  \
# 7            16.05       moveis_decoracao                 41.0
# 71           77.80  utilidades_domesticas                 57.0
# 93           17.84       moveis_decoracao                 63.0
# 241          24.26             automotivo                 58.0
# 309          45.45          esporte_lazer                 45.0
#
#      product_description_lenght  product_photos_qty  product_weight_g  \
# 7                         432.0                 2.0             300.0
# 71                        698.0                 3.0             705.0
# 93                        418.0                 1.0            1500.0
# 241                      1167.0                 1.0            1900.0
# 309                       599.0                 1.0           18500.0
#
#      product_length_cm  product_height_cm  product_width_cm  comment_present
# 7                 35.0               35.0              15.0            False
# 71                34.0               22.0              28.0            False
# 93                45.0               15.0              35.0            False
# 241               90.0               14.0              18.0            False
# 309               22.0               26.0              15.0            False

# %%
negative_silent_orders.order_status.unique(), negative_silent_orders.shape
# Out:
# ([delivered]
#  Categories (1, object): [delivered], (2080, 37))

# %% [markdown]
# It seems that all orders have been submitted, but when ? Let's try to find out !

# %%
late_deliveries = negative_silent_orders[negative_silent_orders['order_delivered_customer_date'] > negative_silent_orders['order_estimated_delivery_date']]

# %%
late_deliveries.head()
# Out:
#                              order_id                       customer_id  \
# 93   6a0a8bfbbe700284feb0845d95e0867f  68451b39b1314302c08c65a29f1140fc
# 241  f31535f21d145b2345e2bf7f09d62322  ed532487db04478dfba09d112649fc13
# 309  16c24987724018f73b746aacfbb5f8e8  ffdc2af7160aed3bad21cbc8ec68c0c5
# 600  b7ed5b357d48b6c8f588c5cf0d7ddf5d  92148a85c89c0da621cdc0e1810a23f7
# 631  cafc9b2f7d35ec42bdb74347cc6e8a70  c9573cc1e246dadca50b2a74f795def3
#
#     order_status order_purchase_timestamp   order_approved_at  \
# 93     delivered      2017-11-22 11:32:22 2017-11-22 11:46:50
# 241    delivered      2018-02-01 07:47:34 2018-02-01 08:10:31
# 309    delivered      2017-05-20 02:48:00 2017-05-23 03:50:25
# 600    delivered      2018-03-10 23:24:50 2018-03-11 00:00:30
# 631    delivered      2018-01-19 00:48:30 2018-01-19 01:21:52
#
#     order_delivered_carrier_date order_delivered_customer_date  \
# 93           2017-11-27 13:39:35           2017-12-28 19:43:00
# 241          2018-02-02 00:24:34           2018-04-23 15:49:34
# 309          2017-06-05 13:58:19           2017-06-16 16:52:02
# 600          2018-03-12 17:08:26           2018-04-17 17:37:54
# 631          2018-01-19 22:41:38           2018-04-04 17:12:36
#
#     order_estimated_delivery_date  payment_sequential payment_type  \
# 93                     2017-12-11                 1.0  credit_card
# 241                    2018-03-05                 2.0      voucher
# 309                    2017-06-09                 1.0       boleto
# 600                    2018-04-02                 1.0  credit_card
# 631                    2018-02-16                 1.0  credit_card
#
#      payment_installments  payment_value                customer_unique_id  \
# 93                    5.0         101.74  781ae350edb16842380e81d7c7feb431
# 241                   1.0         100.00  51ac8560948d44d4ffa33f2680569a20
# 309                   1.0         180.45  49eb55b407f86a1e87d7898594e65c90
# 600                  10.0         173.53  5d81094365fbd7cb0e548f4508fa5e62
# 631                   1.0          55.63  7671178c592895e5beed747367b4a54b
#
#      customer_zip_code_prefix   customer_city customer_state  \
# 93                    20740.0  rio de janeiro             RJ
# 241                   24350.0         niteroi             RJ
# 309                   30130.0  belo horizonte             MG
# 600                   26070.0     nova iguacu             RJ
# 631                   60833.0       fortaleza             CE
#
#                             review_id  review_score    review_comment_title  \
# 93   1dbe272d8884775c73d0d164bd1ff844           1.0  O cliente não comentou
# 241  64c5384f6f6ccdb5b514f1ebfbba5a03           1.0  O cliente não comentou
# 309  fb7793b81898e28816f37c40bef6c9f8           1.0  O cliente não comentou
# 600  0e292b0d5837bdefe75d8c1b1758ac6a           1.0  O cliente não comentou
# 631  10fff4faa197b0a1b7d7b087a7cb1836           1.0  O cliente não comentou
#
#      review_comment_message review_creation_date review_answer_timestamp  \
# 93   O cliente não comentou           2017-12-13     2017-12-19 22:50:36
# 241  O cliente não comentou           2018-03-07     2018-03-07 12:30:01
# 309  O cliente não comentou           2017-06-14     2017-06-14 10:56:09
# 600  O cliente não comentou           2018-04-04     2018-04-04 08:39:27
# 631  O cliente não comentou           2018-02-18     2018-02-18 17:28:40
#
#      order_item_id                         seller_id  \
# 93             1.0  4a3ca9315b744ce9f8e9374361493884
# 241            1.0  91f0eec23d4a61d7d7caeefa3f0ad1ca
# 309            1.0  973f21788dfab357250f69a8dcb7ddee
# 600            1.0  da8622b14eb17ae2831f4ac5b9dab84a
# 631            1.0  b561927807645834b59ef0d16ba55a24
#
#                            product_id shipping_limit_date  price  \
# 93   f8a8f05a35976a91aed5cccc3992c357 2017-11-28 11:46:50   83.9
# 241  f196248e8b5d060cca414a664ea9a76f 2018-02-08 08:10:31  199.0
# 309  f3dbf072e817667fbde052aae313cce1 2017-05-29 03:50:25  135.0
# 600  9565229244e9341fb8c8069879cf73cd 2018-03-15 00:00:30  149.9
# 631  c5841303f830680eb1cdda8be0ff35bf 2018-01-25 01:21:52   38.0
#
#      freight_value product_category_name  product_name_lenght  \
# 93           17.84      moveis_decoracao                 63.0
# 241          24.26            automotivo                 58.0
# 309          45.45         esporte_lazer                 45.0
# 600          23.63       cama_mesa_banho                 60.0
# 631          17.63             papelaria                 33.0
#
#      product_description_lenght  product_photos_qty  product_weight_g  \
# 93                        418.0                 1.0            1500.0
# 241                      1167.0                 1.0            1900.0
# 309                       599.0                 1.0           18500.0
# 600                       234.0                 1.0            1700.0
# 631                       691.0                 2.0             250.0
#
#      product_length_cm  product_height_cm  product_width_cm  comment_present
# 93                45.0               15.0              35.0            False
# 241               90.0               14.0              18.0            False
# 309               22.0               26.0              15.0            False
# 600               34.0                7.0              32.0            False
# 631               27.0                3.0              11.0            False

# %%
late_deliveries.shape
# Out:
# (1047, 37)

# %% [markdown]
# Interesting ! It seems that half of the negative reviews which resulted in not answering to the customer satisfaction survey were orders which actually arrived but late . Let's look at the distribution of the delays.

# %%
late_deliveries['delay'] = ((late_deliveries['order_delivered_customer_date'] - late_deliveries['order_estimated_delivery_date']).dt.days)
# Out:
# C:\Anaconda\envs\ada\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
sns.boxplot(y='delay', data=late_deliveries)

# %% [markdown]
# Let's have a look at the time they received the survey and the time they received the products.

# %%
late_deliveries['delivery_to_survey_delay'] = ((late_deliveries['review_creation_date'] - late_deliveries['order_delivered_customer_date']).dt.days)
# Out:
# C:\Anaconda\envs\ada\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
late_deliveries.delivery_to_survey_delay.hist()

# %% [markdown]
# As we noticed earlier for non silent customers, Olist platform tend to send customer satisfaction survey to customer way before they actually received the product.
#
# Let's look at the customers who did not receive their product late.

# %%
on_time_deliveries = negative_silent_orders[negative_silent_orders['order_delivered_customer_date'] <= negative_silent_orders['order_estimated_delivery_date']]

# %%
on_time_deliveries.head()
# Out:
#                              order_id                       customer_id  \
# 7    76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 71   82bce245b1c9148f8d19a55b9ff70644  388025bec8128ff20ec1a316ed4dcf02
# 414  5a0e5ad33542c79b10be87a344ee0086  917149651e472bef5b609eb58e742eb4
# 565  6ac882284d5fcde113962e178ba0edbb  1bd00f336a9c3b3c35a720f715e7fe58
# 607  01835ef41c5ac66dd9ec6084fa1d0533  6a4ea2081853cd8dd8d7c69cdf86925a
#
#     order_status order_purchase_timestamp   order_approved_at  \
# 7      delivered      2017-01-23 18:29:09 2017-01-25 02:50:47
# 71     delivered      2017-04-20 17:15:46 2017-04-21 05:15:56
# 414    delivered      2017-06-13 11:13:38 2017-06-15 03:03:40
# 565    delivered      2017-12-07 15:40:14 2017-12-12 03:49:32
# 607    delivered      2017-05-11 21:36:10 2017-05-11 21:45:17
#
#     order_delivered_carrier_date order_delivered_customer_date  \
# 7            2017-01-26 14:16:31           2017-02-02 14:08:10
# 71           2017-04-24 09:34:13           2017-05-10 09:17:55
# 414          2017-06-16 15:37:52           2017-06-19 18:06:01
# 565          2017-12-13 22:07:57           2017-12-20 19:05:03
# 607          2017-05-16 08:54:10           2017-05-23 22:13:35
#
#     order_estimated_delivery_date  payment_sequential payment_type  \
# 7                      2017-03-06                 1.0       boleto
# 71                     2017-05-12                 1.0       boleto
# 414                    2017-07-04                 1.0       boleto
# 565                    2018-01-09                 1.0       boleto
# 607                    2017-06-01                 1.0  credit_card
#
#      payment_installments  payment_value                customer_unique_id  \
# 7                     1.0          35.95  39382392765b6dc74812866ee5ee92a7
# 71                    1.0         267.80  f9effeed3df9ae063a58c0759b96f8b2
# 414                   1.0          86.67  572e9e13a44a5e4ac5c42e74b324244f
# 565                   1.0          48.60  620123772a3dcba2bd22515fb40e1fb3
# 607                   1.0          72.14  f64ee7b44a9c2170a0db74d6bc3d1ba8
#
#      customer_zip_code_prefix          customer_city customer_state  \
# 7                     99655.0           faxinalzinho             RS
# 71                    85804.0               cascavel             PR
# 414                   75705.0                catalao             GO
# 565                    8790.0        mogi das cruzes             SP
# 607                   28027.0  campos dos goytacazes             RJ
#
#                             review_id  review_score    review_comment_title  \
# 7    fc4af8aea8ec3f1a3cd181d3d0cadbd5           1.0  O cliente não comentou
# 71   fd793fea4f4a2ddcc956561144b6c04e           1.0  O cliente não comentou
# 414  298a8ef64cf5aced55964933cedc056a           1.0  O cliente não comentou
# 565  4a26f927e05475a99317fcb4c0ec39a8           1.0  O cliente não comentou
# 607  d59858813df002a1fbbc21bf4f66e9e0           1.0  O cliente não comentou
#
#      review_comment_message review_creation_date review_answer_timestamp  \
# 7    O cliente não comentou           2017-02-03     2017-02-05 01:58:35
# 71   O cliente não comentou           2017-05-11     2017-05-12 11:25:49
# 414  O cliente não comentou           2017-06-21     2017-06-24 00:37:45
# 565  O cliente não comentou           2017-12-21     2017-12-21 21:48:12
# 607  O cliente não comentou           2017-05-24     2017-05-27 13:16:16
#
#      order_item_id                         seller_id  \
# 7              1.0  63b9ae557efed31d1f7687917d248a8d
# 71             5.0  c8417879a15366a17c30af34c798c332
# 414            1.0  376a891762bbdecbc02b4b6adec3fdda
# 565            1.0  86ccac0b835037332a596a33b6949ee1
# 607            1.0  cc419e0650a3c5ba77189a1882b7556a
#
#                            product_id shipping_limit_date   price  \
# 7    ac1789e492dcd698c5c10b97a671243a 2017-01-27 18:29:09   19.90
# 71   a5a0e71a81ae65aa335e71c06261e260 2017-04-27 05:15:56  190.00
# 414  622bad99b4296aade0783ebecdd3fa15 2017-06-21 03:03:40   73.90
# 565  88bcd4cc43e257bf69ac62b2540f1c14 2017-12-18 03:49:32   33.50
# 607  bbaef2eadf31fe3ea6702077398be06c 2017-05-18 21:45:17   56.99
#
#      freight_value  product_category_name  product_name_lenght  \
# 7            16.05       moveis_decoracao                 41.0
# 71           77.80  utilidades_domesticas                 57.0
# 414          12.77          esporte_lazer                 47.0
# 565          15.10     relogios_presentes                 55.0
# 607          15.15             perfumaria                 45.0
#
#      product_description_lenght  product_photos_qty  product_weight_g  \
# 7                         432.0                 2.0             300.0
# 71                        698.0                 3.0             705.0
# 414                      1249.0                 1.0             400.0
# 565                       384.0                 1.0             450.0
# 607                      1003.0                 2.0             400.0
#
#      product_length_cm  product_height_cm  product_width_cm  comment_present
# 7                 35.0               35.0              15.0            False
# 71                34.0               22.0              28.0            False
# 414               27.0                6.0              25.0            False
# 565               25.0               10.0              25.0            False
# 607               18.0               11.0              11.0            False

# %%
on_time_deliveries['delivery_delay'] = ((on_time_deliveries['order_estimated_delivery_date'] - on_time_deliveries['order_approved_at']).dt.days)
# Out:
# C:\Anaconda\envs\ada\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
delivery_delay.hist()

# %% [markdown]
# Let's spot the difference with happy silent customers.

# %%
positive_silent_orders = silent_orders[silent_orders['review_score'] == 5]
positive_silent_orders['delivery_delay'] = ((positive_silent_orders['order_estimated_delivery_date'] - positive_silent_orders['order_approved_at']).dt.days)
# Out:
# C:\Anaconda\envs\ada\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
positive_silent_orders.delivery_delay.hist()

# %% [markdown]
# It looks the same... maybe it has something to do with the product !

# %% [markdown]
# ## Topic modelling

# %%
orders.order_approved_at.dtypes
# Out:
# dtype('O')

# %%
orders.order_approved_at
# Out:
# 0        2017-10-02 11:07:15
# 1        2018-07-26 03:24:27
# 2        2018-08-08 08:55:23
# 3        2017-11-18 19:45:59
# 4        2018-02-13 22:20:29
# 5        2017-07-09 22:10:13
# 6        2017-05-16 13:22:11
# 7        2017-01-25 02:50:47
# 8        2017-07-29 12:05:32
# 9        2017-05-16 19:50:18
# 10       2017-07-13 20:10:08
# 11       2018-06-09 03:13:12
# 12       2018-07-25 17:55:14
# 13       2018-03-01 15:10:47
# 14       2018-06-12 23:31:02
# 15       2018-01-02 19:09:04
# 16       2017-12-26 23:50:22
# 17       2017-11-21 00:14:22
# 18       2017-10-26 16:08:14
# 19       2017-09-19 04:04:09
# 20       2018-03-15 09:09:31
# 21       2018-02-03 20:50:22
# 22       2018-01-08 08:07:31
# 23       2018-08-10 03:24:51
# 24       2018-02-22 02:30:46
# 25       2018-06-05 00:35:10
# 26       2018-03-12 03:28:34
# 27       2018-05-03 12:55:01
# 28       2018-02-25 14:47:35
# 29       2017-08-12 02:45:24
#                 ...
# 95950    2017-09-05 04:10:34
# 95951    2018-07-23 12:32:05
# 95952    2017-11-26 19:53:48
# 95953    2018-04-01 16:30:16
# 95954    2017-08-10 21:35:26
# 95955    2018-06-03 18:55:15
# 95956    2018-02-07 12:31:13
# 95957    2017-11-30 18:16:25
# 95958    2017-10-02 08:56:53
# 95959    2017-06-08 02:45:24
# 95960    2017-07-05 17:43:48
# 95961    2018-05-25 17:15:21
# 95962    2017-10-14 03:28:24
# 95963    2017-11-21 20:28:52
# 95964    2018-03-21 20:05:26
# 95965    2017-05-15 10:02:45
# 95966    2018-05-12 13:55:17
# 95967    2018-06-22 21:17:45
# 95968    2017-11-05 16:30:29
# 95969    2018-03-04 23:09:22
# 95970    2017-10-27 15:32:49
# 95971    2017-12-20 10:09:52
# 95972    2017-10-04 20:07:14
# 95973    2017-01-27 01:05:25
# 95974    2017-02-23 09:15:11
# 95975    2017-03-09 09:54:05
# 95976    2018-02-06 13:10:37
# 95977    2017-08-27 15:04:16
# 95978    2018-01-08 21:36:21
# 95979    2018-03-09 11:20:28
# Name: order_approved_at, Length: 95980, dtype: object

# %%
import datetime
    
def validate(date_text):
    try:
        if date_text != datetime.datetime.strptime(date_text, '%Y-%m-%d %H:%M:%S').strftime('%Y-%m-%d %H:%M:%S'):
            raise ValueError
        return True
    except ValueError:
        return False
    
clean_orders = orders[orders['order_purchase_timestamp'].apply(validate) == True]
clean_orders = clean_orders[clean_orders['order_approved_at'].apply(validate) == True]
clean_orders = clean_orders[clean_orders['order_delivered_carrier_date'].apply(validate) == True]
clean_orders = clean_orders[clean_orders['order_estimated_delivery_date'].apply(validate) == True]

# %%
clean_orders.shape, orders.shape
# Out:
# ((95978, 37), (95980, 37))

# %%
clean_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date  payment_sequential payment_type  \
# 0           2017-10-18 00:00:00                 1.0  credit_card
# 1           2018-08-13 00:00:00                 1.0       boleto
# 2           2018-09-04 00:00:00                 1.0  credit_card
# 3           2017-12-15 00:00:00                 1.0  credit_card
# 4           2018-02-26 00:00:00                 1.0  credit_card
#
#    payment_installments  payment_value                customer_unique_id  \
# 0                   1.0          18.12  7c396fd4830fd04220f754e42b4e5bff
# 1                   1.0         141.46  af07308b275d755c9edb36a90c618231
# 2                   3.0         179.12  3a653a41f6f9fc3d2a113cf8398680e8
# 3                   1.0          72.20  7c142cf63193a1473d2e66489a9ae977
# 4                   1.0          28.62  72632f0f9dd73dfee390c9b22eb56dd6
#
#    customer_zip_code_prefix            customer_city customer_state  \
# 0                    3149.0                sao paulo             SP
# 1                   47813.0                barreiras             BA
# 2                   75265.0               vianopolis             GO
# 3                   59296.0  sao goncalo do amarante             RN
# 4                    9195.0              santo andre             SP
#
#                           review_id  review_score    review_comment_title  \
# 0  a54f0611adc9ed256b57ede6b6eb5114           4.0  O cliente não comentou
# 1  8d5266042046a06655c8db133d120ba5           4.0        Muito boa a loja
# 2  e73b67b67587f7644d5bd1a52deb1b01           5.0  O cliente não comentou
# 3  359d03e676b3c069f62cadba8dd3f6e8           5.0  O cliente não comentou
# 4  e50934924e227544ba8246aeb3770dd4           5.0  O cliente não comentou
#
#                               review_comment_message review_creation_date  \
# 0  Não testei o produto ainda, mas ele veio corre...           2017-10-11
# 1                               Muito bom o produto.           2018-08-08
# 2                             O cliente não comentou           2018-08-18
# 3  O produto foi exatamente o que eu esperava e e...           2017-12-03
# 4                             O cliente não comentou           2018-02-17
#
#   review_answer_timestamp  order_item_id                         seller_id  \
# 0     2017-10-12 03:43:48            1.0  3504c0cb71d7fa48d967e0e4c94d59d9
# 1     2018-08-08 18:37:50            1.0  289cdb325fb7e7f891c38608bf9e0962
# 2     2018-08-22 19:07:58            1.0  4869f7a5dfa277a7dca6462dcf3b52b2
# 3     2017-12-05 19:21:58            1.0  66922902710d126a0e7d26b0e3805106
# 4     2018-02-18 13:02:51            1.0  2c9e548be18521d1c43cde1c582c6de8
#
#                          product_id shipping_limit_date   price  \
# 0  87285b34884572647811a353c7ac498a 2017-10-06 11:07:15   29.99
# 1  595fac2a385ac33a80bd5114aec74eb8 2018-07-30 03:24:27  118.70
# 2  aa4383b373c6aca5d8797843e5594415 2018-08-13 08:55:23  159.90
# 3  d0b61bfb1de832b15ba9d266ca96e5b0 2017-11-23 19:45:59   45.00
# 4  65266b2da20d04dbe00c5c2d3bb7859e 2018-02-19 20:31:37   19.90
#
#    freight_value  product_category_name  product_name_lenght  \
# 0           8.72  utilidades_domesticas                 40.0
# 1          22.76             perfumaria                 29.0
# 2          19.22             automotivo                 46.0
# 3          27.20               pet_shop                 59.0
# 4           8.72              papelaria                 38.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       268.0                 4.0             500.0
# 1                       178.0                 1.0             400.0
# 2                       232.0                 1.0             420.0
# 3                       468.0                 3.0             450.0
# 4                       316.0                 4.0             250.0
#
#    product_length_cm  product_height_cm  product_width_cm  comment_present
# 0               19.0                8.0              13.0             True
# 1               19.0               13.0              19.0             True
# 2               24.0               19.0              21.0            False
# 3               30.0               10.0              20.0             True
# 4               51.0               15.0              15.0            False

# %%
clean_orders = clean_orders.astype({"order_status" : 'category', \
                       "order_purchase_timestamp" : 'datetime64[ns]', 
                        "order_approved_at" : 'datetime64[ns]', \
                       "order_delivered_carrier_date" : 'datetime64[ns]', 
                        "order_delivered_customer_date" : 'datetime64[ns]', \
                       "order_estimated_delivery_date" : 'datetime64[ns]', 
                        'review_creation_date':'datetime64[ns]', \
                        "review_answer_timestamp" : 'datetime64[ns]', "shipping_limit_date" : 'datetime64[ns]', \
                        "product_category_name" : 'category', 
                       })

# %%
clean_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95978 entries, 0 to 95979
# Data columns (total 37 columns):
# order_id                         95978 non-null object
# customer_id                      95978 non-null object
# order_status                     95978 non-null category
# order_purchase_timestamp         95978 non-null datetime64[ns]
# order_approved_at                95978 non-null datetime64[ns]
# order_delivered_carrier_date     95978 non-null datetime64[ns]
# order_delivered_customer_date    95978 non-null datetime64[ns]
# order_estimated_delivery_date    95978 non-null datetime64[ns]
# payment_sequential               95978 non-null float64
# payment_type                     95978 non-null object
# payment_installments             95978 non-null float64
# payment_value                    95978 non-null float64
# customer_unique_id               95978 non-null object
# customer_zip_code_prefix         95978 non-null float64
# customer_city                    95978 non-null object
# customer_state                   95978 non-null object
# review_id                        95978 non-null object
# review_score                     95978 non-null float64
# review_comment_title             95978 non-null object
# review_comment_message           95978 non-null object
# review_creation_date             95976 non-null datetime64[ns]
# review_answer_timestamp          95976 non-null datetime64[ns]
# order_item_id                    95976 non-null float64
# seller_id                        95976 non-null object
# product_id                       95976 non-null object
# shipping_limit_date              95976 non-null datetime64[ns]
# price                            95976 non-null float64
# freight_value                    95976 non-null float64
# product_category_name            94624 non-null category
# product_name_lenght              94624 non-null float64
# product_description_lenght       94624 non-null float64
# product_photos_qty               94624 non-null float64
# product_weight_g                 95960 non-null float64
# product_length_cm                95960 non-null float64
# product_height_cm                95960 non-null float64
# product_width_cm                 95960 non-null float64
# comment_present                  95978 non-null bool
# dtypes: bool(1), category(2), datetime64[ns](8), float64(15), object(11)
# memory usage: 25.9+ MB

# %%
clean_orders['delivery_delay'] = (clean_orders['review_creation_date'] - clean_orders['order_estimated_delivery_date']).dt.days

# %%
average_scores_by_sellers = clean_orders.groupby('seller_id').agg({'review_score' : 'mean', 'delivery_delay' : 'mean'})

# %%
average_scores_by_sellers.corr()
# Out:
#                 review_score  delivery_delay
# review_score        1.000000       -0.212353
# delivery_delay     -0.212353        1.000000

# %%
#average_scores_by_sellers.review_score = average_scores_by_sellers.apply(lambda x : round(x))

# %%
average_scores_by_sellers.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000281DC91A0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000281DC926BA8>]],
#       dtype=object)

# %% [markdown]
# ### Clustering the sellers

# %%
from sklearn.cluster import KMeans

data = average_scores_by_sellers.drop_duplicates(subset='review_score')
sse = {}
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(data[['review_score']])
    # Inertia: Sum of distances of samples to their closest cluster center
    sse[k] = kmeans.inertia_

f = plt.plot(list(sse.keys()), list(sse.values()))
abscisse = plt.xlabel("Number of cluster")
ordonne = plt.ylabel("SSE")
title = plt.title('Elbow Curve')
plt.show()

# %% [markdown]
# The optimal number of clusters is 4

# %%
km = KMeans(n_clusters=3, random_state=42).fit(data[['review_score']])
labels = km.labels_

fig = plt.figure(1, figsize=(7,7))
sns.scatterplot(x="delivery_delay", y="review_score", hue=labels, data=data, legend="full", palette=sns.color_palette("Set1", n_colors=3))
title = plt.title('Clustering of sellers based on their average review score')
plt.show()

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date  payment_sequential payment_type  \
# 0           2017-10-18 00:00:00                 1.0  credit_card
# 1           2018-08-13 00:00:00                 1.0       boleto
# 2           2018-09-04 00:00:00                 1.0  credit_card
# 3           2017-12-15 00:00:00                 1.0  credit_card
# 4           2018-02-26 00:00:00                 1.0  credit_card
#
#    payment_installments  payment_value                customer_unique_id  \
# 0                   1.0          18.12  7c396fd4830fd04220f754e42b4e5bff
# 1                   1.0         141.46  af07308b275d755c9edb36a90c618231
# 2                   3.0         179.12  3a653a41f6f9fc3d2a113cf8398680e8
# 3                   1.0          72.20  7c142cf63193a1473d2e66489a9ae977
# 4                   1.0          28.62  72632f0f9dd73dfee390c9b22eb56dd6
#
#    customer_zip_code_prefix            customer_city customer_state  \
# 0                    3149.0                sao paulo             SP
# 1                   47813.0                barreiras             BA
# 2                   75265.0               vianopolis             GO
# 3                   59296.0  sao goncalo do amarante             RN
# 4                    9195.0              santo andre             SP
#
#                           review_id  review_score    review_comment_title  \
# 0  a54f0611adc9ed256b57ede6b6eb5114           4.0  O cliente não comentou
# 1  8d5266042046a06655c8db133d120ba5           4.0        Muito boa a loja
# 2  e73b67b67587f7644d5bd1a52deb1b01           5.0  O cliente não comentou
# 3  359d03e676b3c069f62cadba8dd3f6e8           5.0  O cliente não comentou
# 4  e50934924e227544ba8246aeb3770dd4           5.0  O cliente não comentou
#
#                               review_comment_message review_creation_date  \
# 0  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 1                               Muito bom o produto.  2018-08-08 00:00:00
# 2                             O cliente não comentou  2018-08-18 00:00:00
# 3  O produto foi exatamente o que eu esperava e e...  2017-12-03 00:00:00
# 4                             O cliente não comentou  2018-02-17 00:00:00
#
#   review_answer_timestamp  order_item_id                         seller_id  \
# 0     2017-10-12 03:43:48            1.0  3504c0cb71d7fa48d967e0e4c94d59d9
# 1     2018-08-08 18:37:50            1.0  289cdb325fb7e7f891c38608bf9e0962
# 2     2018-08-22 19:07:58            1.0  4869f7a5dfa277a7dca6462dcf3b52b2
# 3     2017-12-05 19:21:58            1.0  66922902710d126a0e7d26b0e3805106
# 4     2018-02-18 13:02:51            1.0  2c9e548be18521d1c43cde1c582c6de8
#
#                          product_id  shipping_limit_date   price  \
# 0  87285b34884572647811a353c7ac498a  2017-10-06 11:07:15   29.99
# 1  595fac2a385ac33a80bd5114aec74eb8  2018-07-30 03:24:27  118.70
# 2  aa4383b373c6aca5d8797843e5594415  2018-08-13 08:55:23  159.90
# 3  d0b61bfb1de832b15ba9d266ca96e5b0  2017-11-23 19:45:59   45.00
# 4  65266b2da20d04dbe00c5c2d3bb7859e  2018-02-19 20:31:37   19.90
#
#    freight_value  product_category_name  product_name_lenght  \
# 0           8.72  utilidades_domesticas                 40.0
# 1          22.76             perfumaria                 29.0
# 2          19.22             automotivo                 46.0
# 3          27.20               pet_shop                 59.0
# 4           8.72              papelaria                 38.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       268.0                 4.0             500.0
# 1                       178.0                 1.0             400.0
# 2                       232.0                 1.0             420.0
# 3                       468.0                 3.0             450.0
# 4                       316.0                 4.0             250.0
#
#    product_length_cm  product_height_cm  product_width_cm  comment_present
# 0               19.0                8.0              13.0             True
# 1               19.0               13.0              19.0             True
# 2               24.0               19.0              21.0            False
# 3               30.0               10.0              20.0             True
# 4               51.0               15.0              15.0            False

# %%
orders['delivery_delay'] = orders['order_delivered_customer_date'] - orders['order_estimated_delivery_date']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-278-036da37bd738> in <module>()
# ----> 1 orders.delay
#
# C:\Anaconda\envs\ada\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'delay'
